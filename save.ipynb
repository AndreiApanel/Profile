# %%
function isDivideBy (a,b,c) {
	if (c % a == 0 && c % b == 0)
	return true
	else
	return false
}
console.log(isDivideBy (6,12,24))

# %%
function upperCase1 (text) {
	if (typeof text === 'string')

console.log(text[0].toUpperCase() + text.slice(1))
else
console.log('Должна быть строка')
}
a = '5'
upperCase1 (a)

# %%
function test (a) {
	let x;
	x=1;
for (let i=1;i<=a;i++){

x=x*i;
console.log(x);
};

return x;
};
test(7)

# %%
function test (a) {
	let x=0;
	let i=1;
	while (x<=a,i<a) {
		i++;
		if (i % 2 == 0){
x=x+i;
		}
};
console.log(x);
return x;
};
test(5)

# %%
let a;
let b;
const func1 = (a,b,callback) => {
	const c = a-b
	callback(c);
	console.log(c);
}
const func = () => {
const getResult = (newMain) => {
c = newMain;
}

func1(5001,455,getResult)

}
func()

# %%
const newPost = (post, addedAt = Date()) => ({
    ...post,
    addedAt,
})
# не явный возврат функции
const firstPost = {
    id: 1,
    author: 'Nick',
}
# явный возврат функции
console.log(newPost(firstPost))
 const newPost = (post, addedAt = Date()) => {
    const myPost = {
    ...post,
    addedAt,
  }
    return myPost
}

const firstPost = {
    id: 1,
    author: 'Nick',
}

console.log(newPost(firstPost))

# %%
let i = '';
let x = 0;
function my_function(n) {
	x++;
	i+=x + ' ';
	if (x>=n) return;
	my_function(n);
}
my_function(3)
console.log (i)

# %%
function my_function(n) {
	if (n==1) return n;
	if (n>1)
	return my_function(n-1) + ' ' + n;
}
console.log(my_function(8));

# %%
function testStr(a, b) {
	console.log(a.length)
let c = a.concat(b);
c = a.indexOf(b,0);
return console.log(c)	
	}
testStr('This is a test stringsdadadada','test')

# %%
function testArray(a, b) {
	var sum = 0;
	for (var i = 0;i<a.length;i++) {
sum += a[i]
	}
	var sum1=0
	for (var i = 0;i<b.length;i++) {
	sum1 += b[i]
	}
var sum2 = sum + sum1;
	return console.log(sum2)

}
testArray([0, 1, 5, 3],[3])

# %%
let str = a;
	let str1 = b;
	// let array1 = [b];
	let array = str.split('').reverse().join('');
	let array1 = str1.split('').reverse().join('');
	let myArray = [];
	myArray[0]='Иванов';
	myArray[1]=array;
	myArray[2]=array1;
let myResult = myArray.sort().join('')
console.log (myArray)
	
	return console.log (myResult)

# %%
function testArray(a, b) {
	let str = a+b;
	console.log (str)
	let array = str.split('')
console.log (array)
array.unshift('Иванов');
let arr = array.reverse().join('');

	return console.log (arr)
	}


testArray ('45656','65')

# %%
function testDateTime(a, b) {
	let myStr = new Array;
	myStr= a.split(' ');
	let myStr1 = new Array;
	myStr1= b.split(' ');
let firstData = new Date(myStr);
let secondData = new Date(myStr1);
if (+firstData > +secondData ){
	let options = { weekday: 'long'};
	let day = (new Intl.DateTimeFormat('ru-RU', options).format(firstData));
return day.charAt(0).toUpperCase() + day.slice(1);
} else {
	let options = { weekday: 'long'};
	let day1 = (new Intl.DateTimeFormat('ru-RU', options).format(secondData));
	return day1.charAt(0).toUpperCase() + day1.slice(1);
}
// document.write(firstData,secondData)
}
console.log(testDateTime ('03 November 2017 04:17','28 March 1909 00:59'))
// В этом задании в нашу функцию testDateTime передаются две строки вида "03 November 2017 04:17".
// Вам нужно превратить строки в даты, сравнить их. Для той, что больше получить день недели и вернуть его из функции.

// Название дня недели должно быть по-русски, с большой буквы, например: "Понедельник".

// Sample Input 1:

// 19 October 1909 10:27
// 28 March 1909 00:59
// Sample Output 1:

// Вторник

# %%
function testDateTime(a, b) {
	let days = ["Воскресенье", "Понедельник", "Вторник", "Среда", "Четверг", "Пятница", "Суббота"];
	let myDate1 = new Date(a);
	let myDate2 = new Date(b);
if (new Date(a) > new Date(b)) {
	return (days[myDate1.getDay(a)]);
} else {
	return (days[myDate2.getDay(b)]);
}
// document.write(firstData,secondData)
}
console.log(testDateTime ('03 November 2017 04:17','28 March 1909 00:59'))
// В этом задании в нашу функцию testDateTime передаются две строки вида "03 November 2017 04:17".
// Вам нужно превратить строки в даты, сравнить их. Для той, что больше получить день недели и вернуть его из функции.

// Название дня недели должно быть по-русски, с большой буквы, например: "Понедельник".

// Sample Input 1:

// 19 October 1909 10:27
// 28 March 1909 00:59
// Sample Output 1:

// Вторник

# %%
function testErrorFunc(a, func) {
	try {
	(func(a)); //  попытка вызова функции
	} catch (x) {
	return x.name; // вывод сообщения об ошибке
	}
}

# %%
function disemvowel(str) {
  str = str.replace(/[oie]/gi, '');
  return console.log(str);
}
disemvowel ("This website is for losers LOL!")
// убрать согласные

# %%
function isIsogram(str){
	var nos = {};
	var rep = ' ';
	for (var i = 0; i < str.length; i++) {
		if (!nos[str[i]]) {
			rep = rep + str[i];
			nos[str[i]] = 1;
			return false
		}
		else {
			return true
		}
		}
	
}
console.log (isIsogram ('asd'));

# %%
function isIsogram(str){
	var input = str.toLowerCase();
	var output = [...new Set(str)].join``;
	if (input == output) {return true};
	return false
	}
console.log(isIsogram("Dermatoglyphics"))

# %%
Для быстрого создания html структуры нужно использовать сочетания клавиш сразу же (в течение 3-5 секунд) после написания ! или слова html. Эти сочетания клавиш могут быть таковы - "!" "html" + Tab; Enter . В кавычках показано то, что у вас должно быть введено в редакторе для быстрого создания
Для быстрого создания html структуры нужно использовать сочетания клавиш сразу же (в течение 3-5 секунд) после написания ! или слова html. Эти сочетания клавиш могут быть таковы - "!" "html" + Tab; Enter . В кавычках показано то, что у вас должно быть введено в редакторе для быстрого создания

# %%
const logger = function(data){
	console.log(data,new Date());
}
const sum = function (a,b, logger) {
	logger({a,b});
	const result = a+b;
	logger(result);
	return result
}
sum(1,2,logger)
//пример колбек функции

# %%
const newUsers = function (name,age, password) {
	return {
		name,age,password
	}
}
const users = new newUsers('Natasha',30);
console.log(users);

# %%
const Counter = function() {
this.count = 0;
this.increase = function () {
this.count = this.count + 1
}
}
//Счетчик
for(let i = 0; i<buttons.length; i++) {
	const counter = new Counter()
	const currentButton = buttons[i];
	const currentSpan = spans[i];
	currentSpan.innerHTML = counter.count;
//Цикл
	currentButton.addEventListener('click', (event) => {
		counter.increase();
		currentSpan.innerHTML = counter.count;
	})
}

# %%
const callpolice = () => {
	console.log('Call 02');
}
const alarm = (thiefs, callback) => {
	console.log(thiefs);
	if (thiefs < 10) {
		return;
	}
callback (thiefs)
}

for (let i = 1; i<20; i++) {
	setTimeout(() => {
		alarm (i,callpolice)
	}, 100*i);
}

# %%
const array = [1,2,3,4,[5,6,[7,8]]]
const result = [];
const myArr = function(arr) {
	for (let i = 0; i <arr.length; i++) {
		const currentValue = arr[i];
		if(typeof currentValue !== 'number') {
			myArr(currentValue)
		} else {
			result.push(currentValue)
		}

	}
}
myArr(array)
console.log(result);

# %%
const object = {
	name: 'Yahor',
	age: 23,
	passportData:{
		number:3123123,
		id:'934e74r'
	}
};
const object2 = {
	age:54,
	name:'Bosa',
}

const resultObject = {
};
for (let i in object) {
	if(object2[i]) {
		resultObject[i] = object[i] + object2[i];
	}
}
console.log(resultObject);

# %%
const studentOne = {
	name: 'Vasya',
  avgGrade: 4,
}

const studentTwo = {
  name: 'Petya',
  avgGrade: 5,
}

const studentThree = {
  name: 'Anya',
avgGrade:5,
}
const maleStudents = [studentOne, studentTwo]
const femaleStudent = [studentThree]
const allStudents = [...maleStudents,...femaleStudent]

const tenGradeSystemStudents = allStudents.filter((value) => {
	return {
 		...value,
		avgGrade:value.avgGrade *2 
}
});
//метод filter
const redDiplomaStudents = allStudents.filter((value) => value.avgGrade == 5) 


//метод reduce
const ourSchool = allStudents.reduce((acc,value) => ({
students:[...acc.students,value.name],
studentsGrade:[...acc.studentsGrade,value.avgGrade]
}),{
	students:[],
	studentsGrade:[],
})
console.log(ourSchool);

# %%
const numbers = [1,2,3,4,5,6,7];

const numberSum = numbers.reduce((acc, value)=> {
	return acc + value;

},
0 // начальное значение acc!!!
'' // строки 1234567!!!
)
console.log(numberSum);

# %%
#  You will be given an array of numbers which can be used using the String.fromCharCode() (JS), Tools.FromCharCode() (C#) method to convert the number to a character. It is recommended to map over the array of numbers and convert each number to the corresponding ascii character.
var ArrowFunc = function(arr) {
	return arr.map((arr)=> (String.fromCharCode(arr))).join('');
	}
console.log(ArrowFunc([84,101,115,116]))

# %%
#  You are given two sorted arrays that both only contain integers. Your task is to find a way to merge them into a single one, sorted in asc order. Complete the function mergeArrays(arr1, arr2), where arr1 and arr2 are the original sorted arrays.

#  You don't need to worry about validation, since arr1 and arr2 must be arrays with 0 or more Integers. If both arr1 and arr2 are empty, then just return an empty array.

#  Note: arr1 and arr2 may be sorted in different orders. Also arr1 and arr2 may have same integers. Remove duplicated in the returned result.
function mergeArrays(arr1, arr2) {
  arr1 = typeof arr1 !== "undefined" ? arr1 : [];
  arr2 = typeof arr2 !== "undefined" ? arr2 : [];
  let arr3 = [].concat(arr1, arr2).sort((a, b) => a - b);
  let newSet = new Set(arr3);
  let arr4 = Array.from(newSet);
  return arr4;
}

console.log(mergeArrays([1, 3, 5, 7, 9, 11, 12], [1, 2, 3, 4, 5, 10, 12]));

# %%
# For this kata you will have to forget how to add two numbers.
#  In simple terms, our method does not like the principle of carrying over numbers and just writes down every number it calculates :-)

#  You may assume both integers are positive integers.
function add(num1, num2) {
  num1 = num1.toString().split("").reverse();
  num2 = num2.toString().split("").reverse();
  let sum = [];
  let length = Math.max(num1.length, num2.length);
  for (let j = length - 1; j >= 0; j--) {
    sum.push(Number(num1[j] || 0) + Number(num2[j] || 0));
  }

  return +sum.join("");
}
console.log(add(122, 81));

# %%
# Your task is to add a new property users Answer to every object in the array questions. The value of usersAnswer should be set to null. The solution should work for array of any length.
questions.forEach(function(q) {
  q.usersAnswer = null
})

# %%
#  Your task is to add a new property users Answer to every object in the array questions. The value of usersAnswer should be set to null. The solution should work for array of any length.
function colourAssociation(array) {
  let result = [];
  for (let index = 0; index < array.length; index++) {
    result[index] = { [array[index][0]]: array[index][1] };
  }

  return result;
}

console.log(
  colourAssociation([
    ["yellow", "flexible"],
    ["blue", "humerous"],
    ["orange", "lazy"],
    ["pink", "dramatic"],
    ["blue", "mystical"],
    ["yellow", "angry"],
    ["pink", "dramatic"],
    ["white", "humerous"],
    ["red", "lazy"],
    ["white", "mystical"],
  ])
);

# %%
#  Your task is to write a function that takes two or more objects and returns a new object which combines all the input objects.

#  All input object properties will have only numeric values. Objects are combined together so that the values of matching keys are added together.
function combine() {
  let object = {};
  let x = arguments.length;
  for (let i = 0; i < x; i++) {
    for (let key in arguments[i]) {
      if (!object[key]) {
        object[key] = arguments[i][key];
      } else {
        object[key] += arguments[i][key];
      }
    }
  }
  return object;
}
const objC = { a: 5, d: 11, e: 8 };
const objD = { c: 3 };
const objA = { a: 10, b: 20, c: 30 };
const objB = { a: 3, c: 6, d: 3 };
console.log(combine(objA, objB));

# %%
#  Take an integer n (n >= 0) and a digit d (0 <= d <= 9) as an integer.

# Square all numbers k (0 <= k <= n) between 0 and n.

# Count the numbers of digits d used in the writing of all the k**2.

#  Call nb_dig (or nbDig or ...) the function taking n and d as parameters and returning this count.
function nbDig(n, d) {
  var res = 0;
  for (var g = 0; g <= n; g++) {
    var square = (g * g + "").split("");
    square.forEach((s) => (s == d ? res++ : null));
  }
  return res;
}
